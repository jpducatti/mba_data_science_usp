# %% [markdown]
# # <font color="blue"> MBA em Ciência de Dados</font>
# # <font color="blue">Programação para Ciência de Dados</font>
#
# ## <font color="blue">Avaliação Final</font>
# **Material Produzido por Luis Gustavo Nonato**<br>
# **Cemeai - ICMC/USP São Carlos**

# %% [markdown]
# <font color='red'>**ATENÇÃO:** Quando terminar o exame, você deve fazer um "upload" do notebook no _moodle_</font>.

# %% [markdown]
# Para responder as questões abaixo será necessário fazer uso do arquivo <font style="font-family: monaco">covid.csv"</font> disponível para download no _moodle_. As colunas do conjunto de dados fornecem informações sobre:
# - **'Province/State'**: estado ou província onde os casos de COVID19 foram registrados
# - **'Country/Region'**: país onde os casos de COVID19 foram registrados
# - **'Lat'** e **'Long'**: latitude e longitude de referência
# - Datas dos registros ACUMULADOS de casos ao longo da pandemia

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Questão 1 (2 pontos)
# Considerando os dados contidos no arquivo <font style="font-family: monaco">covid.csv"</font>:

# %% [markdown]
# #### a) (0.5 pontos)
# Carregue o arquivo "covid.csv" e armazena em um DataFrame. Imprima as 10 primeiras linhas do DataFrame.

# %%
df = pd.read_csv('covid.csv')

df.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN           Antarctica -71.94990   23.347000
# 6                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 7                           NaN            Argentina -38.41610  -63.616700
# 8                           NaN              Armenia  40.06910   45.038200
# 9  Australian Capital Territory            Australia -35.47350  149.012400
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/28/22  \
# 0        0        0        0        0        0        0  ...   173659
# ...

# %% [markdown]
# #### b) (0.5 pontos)
# Elimine a linha de índice 5 do DataFrame referente ao país ('Country/Region') `Antarctica`.

# %%
df_2 = df.drop([5],axis=0) #removendo a linhda de index 5

df_2.head(10)
# Out:
#                   Province/State       Country/Region       Lat        Long  \
# 0                            NaN          Afghanistan  33.93911   67.709953
# 1                            NaN              Albania  41.15330   20.168300
# 2                            NaN              Algeria  28.03390    1.659600
# 3                            NaN              Andorra  42.50630    1.521800
# 4                            NaN               Angola -11.20270   17.873900
# 6                            NaN  Antigua and Barbuda  17.06080  -61.796400
# 7                            NaN            Argentina -38.41610  -63.616700
# 8                            NaN              Armenia  40.06910   45.038200
# 9   Australian Capital Territory            Australia -35.47350  149.012400
# 10               New South Wales            Australia -33.86880  151.209300
#
#     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/28/22  \
# ...

# %% [markdown]
# #### c) (1 ponto)
# Remova a coluna `Province/State`.

# %%
#removendo a coluna especificada
df_drop_prov = df_2.drop(['Province/State'],axis = 1) 

df_drop_prov.head(10)
# Out:
#          Country/Region       Lat        Long  1/22/20  1/23/20  1/24/20  \
# 0           Afghanistan  33.93911   67.709953        0        0        0
# 1               Albania  41.15330   20.168300        0        0        0
# 2               Algeria  28.03390    1.659600        0        0        0
# 3               Andorra  42.50630    1.521800        0        0        0
# 4                Angola -11.20270   17.873900        0        0        0
# 6   Antigua and Barbuda  17.06080  -61.796400        0        0        0
# 7             Argentina -38.41610  -63.616700        0        0        0
# 8               Armenia  40.06910   45.038200        0        0        0
# 9             Australia -35.47350  149.012400        0        0        0
# 10            Australia -33.86880  151.209300        0        0        0
#
#     1/25/20  1/26/20  1/27/20  1/28/20  ...  2/28/22   3/1/22   3/2/22  \
# 0         0        0        0        0  ...   173659   173879   174073
# ...

# %% [markdown]
# ### Questão 2 (2 pontos)
# Remova do DataFrame todas as linhas cuja soma do total de casos seja menor que 10.000. Imprima quantas linhas foram removidos.

# %%
# Reutilizando o dataframe resultante do exericio 1C
# Encontrando as linhas onde os casos acumulados e totais
# são menores que 10.000
# Criando uma mask com as linhas com soma de casos menor 
# que 10.000
mask = (df_drop_prov[df_drop_prov.columns[-1]] < 10000)

# Criando dataframe que não contenha linhas com soma de 
# casos menor que 10.000
df_drop_rows = df_drop_prov[mask == False]

print('O número de linhas removidas é = ',len(df_drop_prov[mask]), 'linhas')
# Out:
# O número de linhas removidas é =  77 linhas

# %% [markdown]
# ### Questão 3 (3 pontos)
# Alguns países podem aparecer mais de uma vez no DataFrame, pois podem estar fragmentados em estados ou províncias. Sabendo disso, quais os 5 países que apresentaram o maior número de casos considerando a soma de todos os seus estados e províncias na data mais recente de registro (coluna `3/9/22`)?

# %%
# Considerando agora todo o dataframe e removendo
# colunas de latitude, longitude e província. 

df_drop_column  = df.drop(['Province/State','Lat','Long'], axis=1)

# capturando o nome da última coluna
last_column = df_drop_column.columns[-1]

# agrupando os resultados por país, somando 
# os valores do mesmo grupo e ordenando pelo país com maior caso
dfgb_country = df_drop_column.groupby(['Country/Region']).agg(casos = (last_column, 'max')).sort_values(by = 'casos' , ascending= False)

n = 5 #número de top países com maior casos
print('Os ',n ,' paises com maiores números de casos no registro mais recente são:')
print(dfgb_country.head(n))
# Out:
# Os  5  paises com maiores números de casos no registro mais recente são:
#                    casos
# Country/Region
# US              79406602
# India           42980067
# Brazil          29198101
# France          22599285
# United Kingdom  19373884

# %% [markdown]
# ### Questão 4 (3 pontos)
# Faça o gráfico da evolução do número acumulado de contaminados no Brasil (Brazil) e na Itália (Italy) ao longo do tempo.

# %%
dfgb_country_all_col = df_drop_column.groupby(['Country/Region']).sum()
x = dfgb_country_all_col.columns.to_numpy()

data = dfgb_country_all_col.to_numpy()

data_italy = (dfgb_country_all_col[dfgb_country_all_col.index == 'Italy']).to_numpy()
data_italy = data_italy.reshape(data_italy.shape[1],)

data_brazil = (dfgb_country_all_col[dfgb_country_all_col.index == 'Brazil']).to_numpy()
data_brazil = data_brazil.reshape(data_brazil.shape[1],)


print(x.shape)
print(data_brazil.shape)
# Out:
# (778,)
# (778,)

# %%
d = {
    'data' : x,
    'casos_brazil' : data_brazil,
    'casos_italia' : data_italy
}

df_d = pd.DataFrame(d)

df_d['data'] = pd.to_datetime(df_d['data'])
df_d['casos_brazil'] = pd.to_numeric(df_d['casos_brazil'])
df_d['casos_italia'] = pd.to_numeric(df_d['casos_italia'])


print(df_d)
# Out:
#           data  casos_brazil  casos_italia
# 0   2020-01-22             0             0
# 1   2020-01-23             0             0
# 2   2020-01-24             0             0
# 3   2020-01-25             0             0
# 4   2020-01-26             0             0
# ..         ...           ...           ...
# 773 2022-03-05      29040800      12990223
# 774 2022-03-06      29056525      13026112
# 775 2022-03-07      29077831      13048774
# 776 2022-03-08      29152318      13109527
# 777 2022-03-09      29198101      13159342
#
# [778 rows x 3 columns]

# %%
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import matplotlib.dates as md

fig, ax = plt.subplots(figsize = (15, 7))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.0f'))
sns.lineplot(ax = ax, x='data', y='casos_brazil', data=df_d).set_title('Casos Acumulados de COVID-19 - Brazil')
plt.ylabel('Casos Acumulados de COVID-19', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show(True)

# FALTA FAZER O GRÁFICO PARA A ITALIA E AUMENTAR O TAMANHO DO LAYOUT

# # specify the position of the major ticks at the beginning of the week
# ax.xaxis.set_major_locator(md.WeekdayLocator(byweekday = 1))
# # specify the format of the labels as 'year-month-day'
# ax.xaxis.set_major_formatter(md.DateFormatter('%Y-%m-%d'))
# # (optional) rotate by 90° the labels in order to improve their spacing
# plt.setp(ax.xaxis.get_majorticklabels(), rotation = 90)

# ax.xaxis.set_minor_locator(md.DayLocator(interval = 1))

# ax.tick_params(axis = 'x', which = 'major', length = 10)
# ax.tick_params(axis = 'x', which = 'minor', length = 5)



# #  fig, ax = plt.subplots()

# # ax.yaxis.set_major_formatter(FormatStrFormatter('%.0f'))
# # plt.plot(data_brazil, '-r',  label='Brazil')
# # plt.plot(data_italy, '-b',  label='Italy')
# # plt.xticks(fontsize=9)
# # plt.yticks(fontsize=9)
# # plt.legend(fontsize=15)
# # plt.show(True)
