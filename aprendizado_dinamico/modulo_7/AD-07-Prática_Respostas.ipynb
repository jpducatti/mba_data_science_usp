# %% [markdown]
# # Prática 7
#
# Aprendizado Dinâmico
#
# por Cibele Russo (ICMC/USP - São Carlos SP)
#
# MBA em Ciências de Dados

# %% [markdown]
# **1.Faça a leitura das bibliotecas.**

# %% [markdown]
# Nesta prática vamos considerar redes dinâmicas para modelar a temperatura global dos dados em globaltemp.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# **2. Leia os dados do arquivo globaltemp.csv.**

# %%
# Temperatura global

# Diferenças na média de temperatura global. 
# Fonte: https://github.com/mjuez/pytsdatasets/
#pkgdir = '/hdd/MBA/AprendizadoDinamico/Data'
#df = pd.read_csv('globaltemp.csv', index_col=0,parse_dates=True)

df = pd.read_csv('https://raw.githubusercontent.com/cibelerusso/Aprendizado-Dinamico/main/Data/globaltemp.csv', index_col=0,parse_dates=True)
df.index = df.index
df.plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df.head()
# Out:
#             data
# year
# 1880-01-01 -0.20
# 1881-01-01 -0.11
# 1882-01-01 -0.10
# 1883-01-01 -0.20
# 1884-01-01 -0.28

# %% [markdown]
# ##

# %% [markdown]
# **3.  Divida a base em treino e teste, deixando 14 dias para a previsão.**

# %%
len(df)
# Out:
# 136

# %%
len(df)-14
# Out:
# 122

# %%
train = df.iloc[:122]
test = df.iloc[122:]

# %%
train
# Out:
#             data
# year
# 1880-01-01 -0.20
# 1881-01-01 -0.11
# 1882-01-01 -0.10
# 1883-01-01 -0.20
# 1884-01-01 -0.28
# ...          ...
# 1997-01-01  0.48
# 1998-01-01  0.63
# 1999-01-01  0.42
# 2000-01-01  0.42
# 2001-01-01  0.55
#
# [122 rows x 1 columns]

# %% [markdown]
# **4. Padronize os dados para a modelagem.**

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(train)
# Out:
# MinMaxScaler()

# %%
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %% [markdown]
# **5. Considere o gerador de séries temporais, com variados valores para os parâmetros length e batch_size.**

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
# defina o gerador
n_input = 2
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
len(scaled_train)
# Out:
# 122

# %%
len(generator) # n_input = 2
# Out:
# 120

# %%
# Qual é a aparência do primeiro lote?
X,y = generator[0]

# %%
print(f'Dado o array: \n{X.flatten()}');
print(f'Previsão: \n {y}');
# Out:
# Dado o array:
# [0.24545455 0.32727273]
# Previsão:
#  [[0.33636364]]

# %% [markdown]
# **6. Carregue as bibliotecas do keras para as redes dinâmicas.**

# %%
### Pacote ideal do tensorflow = 2.5
### Pacote ideal do keras = 2.6
### Caso necessário, instale o pacote nessas versões

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %% [markdown]
# **7. Defina os lotes pra o processo iterativo.**

# %%
# Vamos redefinir lotes de tamanho 21 para o procedimento iterativo
# Veja mais informações sobre o tamanho do lote http://deeplearningbook.com.br/o-efeito-do-batch-size-no-treinamento-de-redes-neurais-artificiais/

n_input = 7
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %% [markdown]
# **8. Defina o modelo. Ele pode ter uma camada LSTM e uma camada Dense. Teste alternativas.**

# %%
# Defina o modelo
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(n_input, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               40800
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **9. Faça o ajuste do modelo e observe a função de perda.**

# %%
# Ajuste do modelo

model.fit_generator(generator,epochs=100)
# Out:
# C:\Users\leona\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 115/115 [==============================] - 1s 2ms/step - loss: 0.0267
# Epoch 2/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 3/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 4/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0118
# Epoch 5/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0124
# Epoch 6/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0121
# Epoch 7/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 8/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0106
# Epoch 9/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0126
# Epoch 10/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0126
# Epoch 11/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 12/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0109
# Epoch 13/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0108
# Epoch 14/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0103
# Epoch 15/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0099
# Epoch 16/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0102
# Epoch 17/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0104
# Epoch 18/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0112
# Epoch 19/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0103
# Epoch 20/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 21/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0097
# Epoch 22/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0109
# Epoch 23/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0107
# Epoch 24/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0101
# Epoch 25/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0098
# Epoch 26/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0097
# Epoch 27/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0097
# Epoch 28/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0096
# Epoch 29/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0091
# Epoch 30/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0096
# Epoch 31/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0099
# Epoch 32/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0098
# Epoch 33/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 34/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0097
# Epoch 35/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0094
# Epoch 36/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0090
# Epoch 37/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0100
# Epoch 38/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0089
# Epoch 39/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0088
# Epoch 40/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 41/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0093
# Epoch 42/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0090
# Epoch 43/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 44/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0089
# Epoch 45/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0090
# Epoch 46/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0096
# Epoch 47/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 48/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 49/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 50/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 51/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0083
# Epoch 52/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 53/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 54/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 55/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 56/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0086
# Epoch 57/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0096
# Epoch 58/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 59/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 60/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 61/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0083
# Epoch 62/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 63/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 64/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 65/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 66/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 67/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 68/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0083
# Epoch 69/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 70/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 71/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 72/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 73/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 74/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 75/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 76/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 77/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 78/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 79/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 80/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 81/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 82/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 83/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 84/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 85/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 86/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 87/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 88/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 89/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 90/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 91/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 92/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 93/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 94/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 95/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 96/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 97/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 98/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 99/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 100/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0077

# %%
model.history.history.keys()
# Out:
# dict_keys(['loss'])

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %% [markdown]
# **10. Faça a previsão.**

# %%
# Vejamos passo a passo como é feita a previsão, a princípio para a próxima observação usando o tamanho do lote igual a 7

first_eval_batch = scaled_train[-7:]

# %%
first_eval_batch
# Out:
# array([[0.84545455],
#        [0.73636364],
#        [0.86363636],
#        [1.        ],
#        [0.80909091],
#        [0.80909091],
#        [0.92727273]])

# %%
# Agora vamos considerar as previsões para as próximas 21 observações e comparar com a base de teste

test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # obter a previsão de tempo 1 antecipadamente ([0] é para pegar apenas o número em vez de [array])
    current_pred = model.predict(current_batch)[0]
    
    # predição
    test_predictions.append(current_pred) 
    
    # atualize a rodada para agora incluir a previsão e descartar o primeiro valor
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
test_predictions
# Out:
# [array([0.9323747], dtype=float32),
#  array([0.85277355], dtype=float32),
#  array([0.93172765], dtype=float32),
#  array([1.0880016], dtype=float32),
#  array([0.97020197], dtype=float32),
#  array([0.9451967], dtype=float32),
#  array([1.0444181], dtype=float32),
#  array([1.0814062], dtype=float32),
#  array([1.0293252], dtype=float32),
#  array([1.092088], dtype=float32),
#  array([1.2667899], dtype=float32),
#  array([1.2145313], dtype=float32),
#  array([1.1857203], dtype=float32),
#  array([1.284625], dtype=float32)]

# %%
scaled_test
# Out:
# array([[1.        ],
#        [0.99090909],
#        [0.92727273],
#        [1.05454545],
#        [1.        ],
#        [1.02727273],
#        [0.91818182],
#        [1.00909091],
#        [1.08181818],
#        [0.97272727],
#        [1.        ],
#        [1.02727273],
#        [1.10909091],
#        [1.21818182]])

# %% [markdown]
# **11. Retorne da padronização.**

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
true_predictions
# Out:
# array([[0.55561219],
#        [0.4680509 ],
#        [0.55490041],
#        [0.72680177],
#        [0.59722217],
#        [0.56971636],
#        [0.67885991],
#        [0.71954686],
#        [0.66225777],
#        [0.73129678],
#        [0.9234689 ],
#        [0.86598443],
#        [0.83429236],
#        [0.94308756]])

# %%
# Possivelmente encontraremos warnings aqui
test['Predictions'] = true_predictions
# Out:
# <ipython-input-35-b5be589fc0d6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions

# %% [markdown]
# **12. Visualize os resultados, comparando as previsões com a base de teste.**

# %%
test.plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='year'>
